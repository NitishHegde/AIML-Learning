# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# read data
df = pd.read_csv("htWtData.csv")
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
plt.scatter(df['Weight'], df['Height'])

# %%
# divide the dataset into independent and dependent features
X=df[['Weight']]
y=df['Height'] #dependent

# %%
X
# Out:
#     Weight
# 0       45
# 1       58
# 2       48
# 3       60
# 4       70
# 5       78
# 6       80
# 7       90
# 8       95
# 9       78
# 10      82
# 11      95
# 12     105
# 13     100
# 14      85
# 15      78
# 16      50
# 17      65
# 18      76
# 19      87
# 20      45
# 21      56
# 22      72

# %%
y
# Out:
# 0     120
# 1     135
# 2     123
# 3     145
# 4     160
# 5     162
# 6     163
# 7     175
# 8     182
# 9     170
# 10    176
# 11    182
# 12    175
# 13    183
# 14    170
# 15    177
# 16    140
# 17    159
# 18    150
# 19    167
# 20    129
# 21    140
# 22    160
# Name: Height, dtype: int64

# %%
from sklearn.model_selection import train_test_split

Xtrain, Xtest, ytrain, ytest = train_test_split(X,y,test_size=0.20, random_state=42)

# %%
Xtrain.shape
# Out:
# (18, 1)

# %%
Xtest.shape
# Out:
# (5, 1)

# %%
# standardize the data - Train independent data only
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
Xtrain = scaler.fit_transform(Xtrain)
Xtest = scaler.transform(Xtest)
# Out:
# c:\Users\admin\anaconda3\Lib\site-packages\sklearn\base.py:486: UserWarning: X has feature names, but StandardScaler was fitted without feature names
#   warnings.warn(

# %%
plt.scatter(Xtrain,ytrain)

# %%
# train the model
from sklearn.linear_model import LinearRegression

regressor = LinearRegression()

# %%
regressor.fit(Xtrain,ytrain)
# Out:
# LinearRegression()

# %%
regressor.coef_
# Out:
# array([17.03440872])

# %%
regressor.intercept_
# Out:
# 157.5

# %%
plt.scatter(Xtrain,ytrain)
plt.plot(Xtrain,regressor.predict(Xtrain),'r')
